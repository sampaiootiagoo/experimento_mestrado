# %%
import openai
client = openai.OpenAI(
    api_key="sk-LBdHJkXhsyMc7aK9tYHqvQ",
    base_url="https://ia-router.unb.br/" # LiteLLM Proxy is OpenAI compatible, Read More: Langchain, OpenAI SDK, LlamaIndex, Instructor, Curl examples | liteLLM
)
 
response = client.chat.completions.create(
    model="UnB-Qwen/Qwen3-Coder-30B-A3B-Instruct", # model to send to the proxy
    messages = [
        {
            "role": "user",
            "content": "O que é o mundo"
        }
    ]
)
 
print(response)
Langchain, OpenAI SDK, LlamaIndex, Instructor, Curl examples | liteLLM
LiteLLM Proxy is OpenAI-Compatible, and supports:

# %%
import openai
client = openai.OpenAI(
    api_key="sk-LBdHJkXhsyMc7aK9tYHqvQ",
    base_url="https://ia-router.unb.br/" # LiteLLM Proxy is OpenAI compatible, Read More: Langchain, OpenAI SDK, LlamaIndex, Instructor, Curl examples | liteLLM
)
 
response = client.chat.completions.create(
    model="UnB-Llama-3.3-70B-Instruct", # model to send to the proxy
    messages = [
        {
            "role": "user",
            "content": "O que é o mundo"
        }
    ]
)
 
print(response)
